# %%
# import requirements
import numpy as np
import pandas as pd

# %%
# Create dataset
data = {
    'Budget': [10, 50, 20, 100, 30],
    'Is_Action': [0, 1, 0, 1, 0],
    'Revenue': [25, 120, 45, 250, 70]
}

df = pd.DataFrame(data)

x = df[["Budget", "Is_Action"]]
print(x)
